# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Lifestyle_and_Health_Risk_Prediction_Synthetic_Dataset .csv')
df.head()
# Out:
#    age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 0   56      67     195      low    6.1       medium     yes     yes  17.6
# 1   69      76     170     high    6.9         high      no      no  26.3
# 2   46     106     153     high    6.6          low     yes      no  45.3
# 3   32      54     186   medium    8.5       medium      no      no  15.6
# 4   60      98     195     high    8.0          low      no      no  25.8
#
#   health_risk
# 0        high
# 1        high
# 2        high
# 3         low
# 4        high

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           5000 non-null   int64
#  1   weight        5000 non-null   int64
#  2   height        5000 non-null   int64
#  3   exercise      5000 non-null   object
#  4   sleep         5000 non-null   float64
#  5   sugar_intake  5000 non-null   object
#  6   smoking       5000 non-null   object
#  7   alcohol       5000 non-null   object
#  8   bmi           5000 non-null   float64
#  9   health_risk   5000 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#                age       weight       height        sleep         bmi
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.00000
# mean     48.805600    77.359200   171.933200     6.997060    26.84388
# std      17.906991    18.714567    15.822225     1.432849     8.25249
# min      18.000000    45.000000   145.000000     3.000000    11.40000
# 25%      34.000000    61.000000   158.000000     6.000000    20.30000
# 50%      49.000000    77.000000   171.500000     7.000000    26.00000
# 75%      64.000000    94.000000   186.000000     8.000000    32.40000
# max      79.000000   109.000000   199.000000    10.000000    51.40000

# %%
df.isnull()
# Out:
#         age  weight  height  exercise  sleep  sugar_intake  smoking  alcohol  \
# 0     False   False   False     False  False         False    False    False
# 1     False   False   False     False  False         False    False    False
# 2     False   False   False     False  False         False    False    False
# 3     False   False   False     False  False         False    False    False
# 4     False   False   False     False  False         False    False    False
# ...     ...     ...     ...       ...    ...           ...      ...      ...
# 4995  False   False   False     False  False         False    False    False
# 4996  False   False   False     False  False         False    False    False
# 4997  False   False   False     False  False         False    False    False
# 4998  False   False   False     False  False         False    False    False
# 4999  False   False   False     False  False         False    False    False
#
#         bmi  health_risk
# ...

# %%
df.notnull()
# Out:
#        age  weight  height  exercise  sleep  sugar_intake  smoking  alcohol  \
# 0     True    True    True      True   True          True     True     True
# 1     True    True    True      True   True          True     True     True
# 2     True    True    True      True   True          True     True     True
# 3     True    True    True      True   True          True     True     True
# 4     True    True    True      True   True          True     True     True
# ...    ...     ...     ...       ...    ...           ...      ...      ...
# 4995  True    True    True      True   True          True     True     True
# 4996  True    True    True      True   True          True     True     True
# 4997  True    True    True      True   True          True     True     True
# 4998  True    True    True      True   True          True     True     True
# 4999  True    True    True      True   True          True     True     True
#
#        bmi  health_risk
# 0     True         True
# ...

# %%
df.tail()
# Out:
#       age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 4995   42      75     187   medium    7.2          low      no      no  21.4
# 4996   39      86     183      low    7.4          low      no      no  25.7
# 4997   48      56     194     none    7.2         high     yes     yes  14.9
# 4998   34     109     148   medium    9.9       medium      no      no  49.8
# 4999   72      47     149     high    6.3       medium      no      no  21.2
#
#      health_risk
# 4995         low
# 4996        high
# 4997        high
# 4998         low
# 4999         low

# %%
df.sample()
# Out:
#      age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 966   50      64     161     none    6.3       medium     yes      no  24.7
#
#     health_risk
# 966        high

# %%
df.sample(12)
# Out:
#       age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 2740   37      51     155   medium    9.0          low      no      no  21.2
# 1074   32      89     169     high    8.6       medium      no      no  31.2
# 3749   72      97     171     none    7.0          low      no      no  33.2
# 4036   73      57     146     high    7.6       medium      no      no  26.7
# 3833   68      86     156   medium    5.5       medium      no      no  35.3
# 2776   61      50     175   medium    5.9       medium      no      no  16.3
# 1262   61      61     196      low    7.8          low      no     yes  15.9
# 2978   47      46     159     high    7.4         high      no      no  18.2
# 1826   44      50     168      low    6.3          low      no      no  17.7
# 3637   41      65     146      low    5.2       medium     yes     yes  30.5
# 4277   40     103     197      low    7.0         high     yes      no  26.5
# ...

# %%
df.shape
# Out:
# (5000, 10)

# %%
df.isnull().sum()
# Out:
# age             0
# weight          0
# height          0
# exercise        0
# sleep           0
# sugar_intake    0
# smoking         0
# alcohol         0
# bmi             0
# health_risk     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 0      56      67     195      low    6.1       medium     yes     yes  17.6
# 1      69      76     170     high    6.9         high      no      no  26.3
# 2      46     106     153     high    6.6          low     yes      no  45.3
# 3      32      54     186   medium    8.5       medium      no      no  15.6
# 4      60      98     195     high    8.0          low      no      no  25.8
# ...   ...     ...     ...      ...    ...          ...     ...     ...   ...
# 4995   42      75     187   medium    7.2          low      no      no  21.4
# 4996   39      86     183      low    7.4          low      no      no  25.7
# 4997   48      56     194     none    7.2         high     yes     yes  14.9
# 4998   34     109     148   medium    9.9       medium      no      no  49.8
# 4999   72      47     149     high    6.3       medium      no      no  21.2
#
#      health_risk
# 0           high
# ...

# %%
#plotting a histogram for the age and bmi:
plt.figure(figsize=(14,6))
sns.histplot(df['bmi'],bins=30,kde=True)
plt.title('bmi')
plt.xlabel('age')
plt.ylabel('bmi')
plt.show()

# %%
#plotting a histogram for all numerical valued columns 
df[df.columns[:10]].hist(bins=30,figsize=(10,8))
plt.show()

# %%
#scatter plotfor each feature against the target variable
plt.figure(figsize=(15,30))
for num,column in enumerate(df.columns):
    if column!='bmi':
        plt.subplot(7,3,num+1)
        plt.scatter(df[column],df['weight'])
        plt.xlabel(column)
        plt.ylabel('age')
        plt.title(f'{column} vs bmi')
plt.tight_layout()
plt.show()

# %%
df_new = df.drop(columns=['exercise','sugar_intake','smoking','alcohol','health_risk'])

# %%
#box plot for each feature against the target variable this checks for the outliers
plt.figure(figsize=(15,30))
for num,column in enumerate(df_new.columns):
    if column!='bmi':
        plt.subplot(7,3,num+1)
        sns.boxplot(df[column])
        plt.xlabel(column)
        #sns.boxplot(df['generated power_kw'])
       # plt.ylabel('generated power (kw)')
       # plt.title(f'{column}vs Generated power')
#plt.tight_layout()
plt.show()

# %%
df_new.head(10)
# Out:
#    age  weight  height  sleep   bmi
# 0   56      67     195    6.1  17.6
# 1   69      76     170    6.9  26.3
# 2   46     106     153    6.6  45.3
# 3   32      54     186    8.5  15.6
# 4   60      98     195    8.0  25.8
# 5   25      96     160    3.8  37.5
# 6   78      64     168    9.9  22.7
# 7   38      76     194    6.6  20.2
# 8   56      58     158    9.6  23.2
# 9   75      94     147    8.1  43.5

# %%
df
# Out:
#       age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 0      56      67     195      low    6.1       medium     yes     yes  17.6
# 1      69      76     170     high    6.9         high      no      no  26.3
# 2      46     106     153     high    6.6          low     yes      no  45.3
# 3      32      54     186   medium    8.5       medium      no      no  15.6
# 4      60      98     195     high    8.0          low      no      no  25.8
# ...   ...     ...     ...      ...    ...          ...     ...     ...   ...
# 4995   42      75     187   medium    7.2          low      no      no  21.4
# 4996   39      86     183      low    7.4          low      no      no  25.7
# 4997   48      56     194     none    7.2         high     yes     yes  14.9
# 4998   34     109     148   medium    9.9       medium      no      no  49.8
# 4999   72      47     149     high    6.3       medium      no      no  21.2
#
#      health_risk
# 0           high
# ...

# %%
df.head(10)
# Out:
#    age  weight  height exercise  sleep sugar_intake smoking alcohol   bmi  \
# 0   56      67     195      low    6.1       medium     yes     yes  17.6
# 1   69      76     170     high    6.9         high      no      no  26.3
# 2   46     106     153     high    6.6          low     yes      no  45.3
# 3   32      54     186   medium    8.5       medium      no      no  15.6
# 4   60      98     195     high    8.0          low      no      no  25.8
# 5   25      96     160   medium    3.8       medium      no      no  37.5
# 6   78      64     168   medium    9.9         high      no      no  22.7
# 7   38      76     194      low    6.6       medium     yes      no  20.2
# 8   56      58     158   medium    9.6       medium      no      no  23.2
# 9   75      94     147     none    8.1       medium     yes      no  43.5
#
#   health_risk
# 0        high
# 1        high
# 2        high
# 3         low
# 4        high
# 5        high
# 6        high
# 7        high
# ...

# %%
df.shape
# Out:
# (5000, 10)

# %%
df_new.head(20)
# Out:
#     age  weight  height  sleep   bmi
# 0    56      67     195    6.1  17.6
# 1    69      76     170    6.9  26.3
# 2    46     106     153    6.6  45.3
# 3    32      54     186    8.5  15.6
# 4    60      98     195    8.0  25.8
# 5    25      96     160    3.8  37.5
# 6    78      64     168    9.9  22.7
# 7    38      76     194    6.6  20.2
# 8    56      58     158    9.6  23.2
# 9    75      94     147    8.1  43.5
# 10   36      72     178    7.4  22.7
# 11   40      97     177    6.9  31.0
# 12   28      68     194   10.0  18.1
# 13   28      66     168    6.6  23.4
# 14   41      74     153    6.0  31.6
# 15   70     107     157    6.1  43.4
# 16   53      48     146    7.0  22.5
# 17   57     103     151    7.0  45.2
# 18   41      52     192    8.5  14.1
# 19   20      56     165    8.1  20.6

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
X=df_new.drop('bmi',axis=1)
y=df_new['bmi']

# %%
#split dataset to train and test
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=30)

# %%
#scale the features
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
#train the model
model=LinearRegression()
model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
#evaluate model
y_pred=model.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
print(f'Mean Absolute Error:{mae}')
# Out:
# Mean Absolute Error:1.0654752422439406

# %%
from sklearn.metrics import r2_score
y_pred_train=model.predict(X_train_scaled)
r2_train=r2_score(y_train,y_pred_train)
print(f'Training R² score:{r2_train}')
# Out:
# Training R² score:0.9728264800114009

# %%
df_new1=df.drop(columns=['exercise','sugar_intake','smoking','alcohol'])
df_new1
# Out:
#       age  weight  height  sleep   bmi health_risk
# 0      56      67     195    6.1  17.6        high
# 1      69      76     170    6.9  26.3        high
# 2      46     106     153    6.6  45.3        high
# 3      32      54     186    8.5  15.6         low
# 4      60      98     195    8.0  25.8        high
# ...   ...     ...     ...    ...   ...         ...
# 4995   42      75     187    7.2  21.4         low
# 4996   39      86     183    7.4  25.7        high
# 4997   48      56     194    7.2  14.9        high
# 4998   34     109     148    9.9  49.8         low
# 4999   72      47     149    6.3  21.2         low
#
# [5000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.tree import plot_tree

# %%
df_new1
# Out:
#       age  weight  height  sleep   bmi health_risk
# 0      56      67     195    6.1  17.6        high
# 1      69      76     170    6.9  26.3        high
# 2      46     106     153    6.6  45.3        high
# 3      32      54     186    8.5  15.6         low
# 4      60      98     195    8.0  25.8        high
# ...   ...     ...     ...    ...   ...         ...
# 4995   42      75     187    7.2  21.4         low
# 4996   39      86     183    7.4  25.7        high
# 4997   48      56     194    7.2  14.9        high
# 4998   34     109     148    9.9  49.8         low
# 4999   72      47     149    6.3  21.2         low
#
# [5000 rows x 6 columns]

# %%
X=df_new1[['age','weight','height','sleep','bmi']]
y=df_new1['health_risk']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=30)

# %%
model=DecisionTreeClassifier(max_depth=4,random_state=30)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=30)

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array(['low', 'low', 'high', 'high', 'high', 'low', 'low', 'high', 'high',
#        'high', 'low', 'low', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'low', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'low', 'high', 'low', 'high',
#        'low', 'high', 'high', 'low', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'low', 'low', 'high', 'low', 'low', 'high',
#        'high', 'high', 'low', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'high', 'high', 'low', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low',
#        'high', 'high', 'low', 'high', 'high', 'low', 'low', 'high', 'low',
#        'high', 'high', 'high', 'high', 'low', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'low', 'high', 'low', 'high', 'low', 'high', 'high', 'high',
# ...

# %%
#printing accuracy score
accuracy=accuracy_score(y_test,y_pred)
print('accuracy_score:',accuracy)
# Out:
# accuracy_score: 0.837

# %%
#confusion matrix
conf_matrix=confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix,annot=True,fmt='d',cmap='Blues',xticklabels=['low_health_risk','high_health_risk'],yticklabels=['low_health_risk','high_health_risk'])
plt.xlabel('predicted')
plt.ylabel('Actual')
plt.title('confusion_matrix')
plt.show()

# %%
#classification report
print(classification_report(y_test,y_pred,target_names=['low_health_risk','high_health_risk']))
# Out:
#                   precision    recall  f1-score   support
#
#  low_health_risk       0.85      0.93      0.89       703
# high_health_risk       0.78      0.62      0.69       297
#
#         accuracy                           0.84      1000
#        macro avg       0.82      0.78      0.79      1000
#     weighted avg       0.83      0.84      0.83      1000

# %%
plt.figure(figsize=(18,9))
plot_tree(model,feature_names=X.columns,class_names=['low_health_risk','high_health_risk'],filled=True,rounded=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
df_new1
# Out:
#       age  weight  height  sleep   bmi health_risk
# 0      56      67     195    6.1  17.6        high
# 1      69      76     170    6.9  26.3        high
# 2      46     106     153    6.6  45.3        high
# 3      32      54     186    8.5  15.6         low
# 4      60      98     195    8.0  25.8        high
# ...   ...     ...     ...    ...   ...         ...
# 4995   42      75     187    7.2  21.4         low
# 4996   39      86     183    7.4  25.7        high
# 4997   48      56     194    7.2  14.9        high
# 4998   34     109     148    9.9  49.8         low
# 4999   72      47     149    6.3  21.2         low
#
# [5000 rows x 6 columns]

# %%
X=df_new1[['age','weight','height','sleep','bmi']]
y=df_new1['health_risk']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=32)

# %%
model=RandomForestClassifier(n_estimators=100,random_state=32)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=32)

# %%
#predict on the dataset
y_pred=model.predict(X_test)
y_pred
# Out:
# array(['low', 'high', 'high', 'low', 'high', 'high', 'low', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'low', 'high', 'low', 'high', 'low', 'high', 'high', 'low',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'low', 'high', 'high', 'high', 'high', 'low',
#        'high', 'high', 'low', 'high', 'high', 'low', 'low', 'high', 'low',
#        'high', 'high', 'low', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low',
#        'high', 'low', 'high', 'high', 'high', 'low', 'high', 'high',
#        'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high',
#        'high', 'high', 'low', 'high', 'high', 'low', 'low', 'high',
#        'high', 'high', 'low', 'high', 'high', 'high', 'high', 'high',
# ...

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.822

# %%
conf_matrix=confusion_matrix(y_test,y_pred)
conf_matrix
# Out:
# array([[640,  77],
#        [101, 182]])

# %%
conf_matrix=confusion_matrix(y_test,y_pred)
sns.heatmap(conf_matrix,annot=True,cmap='Reds',fmt='d',xticklabels=['low_health_risk','high_health_risk'],yticklabels=['low_health_risk','high_health_risk'])
plt.xlabel('actual')
plt.ylabel('predicted')
plt.title('confusion_matrix')
plt.show()

# %%
#printing classification report
print(classification_report(y_test,y_pred,target_names=['low_health_risk','high_health_risk']))
# Out:
#                   precision    recall  f1-score   support
#
#  low_health_risk       0.86      0.89      0.88       717
# high_health_risk       0.70      0.64      0.67       283
#
#         accuracy                           0.82      1000
#        macro avg       0.78      0.77      0.77      1000
#     weighted avg       0.82      0.82      0.82      1000
